# %%
import pandas as pd
# !ls
# Out:
#  atricals			   'prob_tag_with_ pymorphy.ipynb'
#  cloze_task_average_accuracy.xlsx   res.csv
#  cloze_task_raw_data.xlsx	    result_tag_new.xls
#  Compare_data.ipynb		    result_tag_new.xlsx
#  diction_for_tag_replacing.ipynb    result_tag_to_compare.xlsx
#  LSTM_probability.xlsx		    result_tag.xls
#  LSTM_prob_w_pos.xlsx		    tag_clearing.ipynb
#  new_comparing.ipynb		    Tag_cloze_task.ipynb
#  output.xlsx			    Untitled1.ipynb

# %% [markdown]
# drop all rows were we don't have a contex as a stimulus

# %%
row_data = pd.read_excel('cloze_task_raw_data.xlsx')
print(row_data.shape)
row_data = row_data[row_data['shown'] != 'Введите первое слово']
print(row_data.shape)
# Out:
# (64645, 16)
# (57836, 16)

# %%
def clear(x):
    flag=0
    if (len(x)==1) and (x not in 'ксявуоиа'):
        flag+=1
    for i in x:
        if i not in 'ячсмитьбюэждлорпавыфйцукенгшщзхъЯЧСМИТЬБЮФЫВАПРОЛДЖЭЪХЗЩЙЦШУГКНЕ':
             flag+=1
    if flag==0:
        return x
    else:
        return 0
row_data.answer = row_data.answer.astype(str)
row_data.answer = row_data.answer.apply(clear)
row_data = row_data[row_data['answer']!=0]
row_data.shape
# Out:
# (57346, 16)

# %% [markdown]
# Count number of different answer for each stimulus and alse a index of confusion for rows.
# If in experement we have 16 attempts to add the contex, when index of confusion is equel 16/max(all quantities of responses for each stimulus). Smaller the value of confuision, than we can be more confident about this example)

# %%
sub_data = row_data[['shown', 'answer', 'word.id']]
grop_data = sub_data[['shown', 'answer']].groupby('shown').size()
grop_data = grop_data.reset_index(level=['shown'])
grop_data.columns = ['shown', 'summ']
grop_data['confusion'] = 1 - grop_data.summ/max(grop_data['summ'])
grop_data
# Out:
#                                                   shown  summ  confusion
# 0                                                     А    15   0.978571
# 1                                           А промывать    15   0.978571
# 2                                    А промывать манную    15   0.978571
# 3                              А промывать манную крупу    15   0.978571
# 4                        А промывать манную крупу перед    15   0.978571
# 5                   А промывать манную крупу перед тем‚    15   0.978571
# 6               А промывать манную крупу перед тем‚ как    15   0.978571
# 7        А промывать манную крупу перед тем‚ как варить    15   0.978571
# 8     А промывать манную крупу перед тем‚ как варить...    15   0.978571
# 9     А промывать манную крупу перед тем‚ как варить...    15   0.978571
# 10                                                Автор    63   0.910000
# 11                                    Автор принадлежит    63   0.910000
# 12                                  Автор принадлежит к    62   0.911429
# 13                            Автор принадлежит к числу    64   0.908571
# 14                  Автор принадлежит к числу последних    62   0.911429
# 15       Автор принадлежит к числу последних свидетелей    63   0.910000
# 16    Автор принадлежит к числу последних свидетелей...    62   0.911429
# 17    Автор принадлежит к числу последних свидетелей...    59   0.915714
# 18    Автор принадлежит к числу последних свидетелей...    63   0.910000
# 19                                                    В   700   0.000000
# 20                                          В багажнике    61   0.912857
# 21                                     В багажнике были    62   0.911429
# 22                             В багажнике были лопата‚    61   0.912857
# 23                         В багажнике были лопата‚ лом    62   0.911429
# 24                       В багажнике были лопата‚ лом и    61   0.912857
# 25                                            В вопросе    19   0.972857
# 26                                 В вопросе послышался    18   0.974286
# 27                           В вопросе послышался упрёк    19   0.972857
# 28                В вопросе послышался упрёк командиру‚    19   0.972857
# 29         В вопросе послышался упрёк командиру‚ словно    19   0.972857
# ...                                                 ...   ...        ...
# 1139                                      Я люблю салат    91   0.870000
# 1140                                   Я люблю салат из    91   0.870000
# 1141                          Я люблю салат из картошки    91   0.870000
# 1142                        Я люблю салат из картошки с    91   0.870000
# 1143               Я люблю салат из картошки с зеленью‚    91   0.870000
# 1144  Я люблю салат из картошки с зеленью‚ заправленный    91   0.870000
# 1145  Я люблю салат из картошки с зеленью‚ заправлен...    90   0.871429
# 1146  Я люблю салат из картошки с зеленью‚ заправлен...    90   0.871429
# 1147                                          Я сделала    87   0.875714
# 1148                                      Я сделала шаг    90   0.871429
# 1149                           Я сделала шаг навстречу:    85   0.878571
# 1150                  Я сделала шаг навстречу: приехала    89   0.872857
# 1151                Я сделала шаг навстречу: приехала к    89   0.872857
# 1152           Я сделала шаг навстречу: приехала к ней‚    88   0.874286
# 1153  Я сделала шаг навстречу: приехала к ней‚ попросив    89   0.872857
# 1154  Я сделала шаг навстречу: приехала к ней‚ попро...    89   0.872857
# 1155                                          Я сказал‚    15   0.978571
# 1156                                      Я сказал‚ что    15   0.978571
# 1157                              Я сказал‚ что русский    15   0.978571
# 1158                       Я сказал‚ что русский солдат    15   0.978571
# 1159                 Я сказал‚ что русский солдат омоет    14   0.980000
# 1160          Я сказал‚ что русский солдат омоет сапоги    15   0.978571
# 1161        Я сказал‚ что русский солдат омоет сапоги в    15   0.978571
# 1162  Я сказал‚ что русский солдат омоет сапоги в Ин...    14   0.980000
# 1163                                          Я слезал‚    18   0.974286
# 1164                                    Я слезал‚ щупал    17   0.975714
# 1165                             Я слезал‚ щупал стога‚    17   0.975714
# 1166                       Я слезал‚ щупал стога‚ чтобы    17   0.975714
# 1167               Я слезал‚ щупал стога‚ чтобы узнать‚    17   0.975714
# 1168         Я слезал‚ щупал стога‚ чтобы узнать‚ сухие    15   0.978571
#
# [1169 rows x 3 columns]

# %% [markdown]
# Count the quantity of different response for each stimulus

# %%
grop_dats_0 = sub_data[['shown', 'answer']].groupby(['shown','answer']).size()
grop_dats_0 = grop_dats_0.reset_index(level=['shown', 'answer'])
grop_dats_0.columns = ['shown', 'answer', 'freq']
grop_dats_0.head()
# Out:
#   shown  answer  freq
# 0     А     вот     1
# 1     А     где     1
# 2     А     ему     1
# 3     А   зачем     1
# 4     А  знаете     1

# %% [markdown]
# Merge tables

# %%
data_res =  sub_data.merge(grop_data, left_on='shown', right_on='shown', how='outer')
data_res =  data_res.merge(grop_dats_0, left_on=['shown','answer'], right_on=['shown','answer'], how='outer')
data_res.head()
# Out:
#   shown  answer    word.id  summ  confusion  freq
# 0     А     вот  промывать    15   0.978571     1
# 1     А     где  промывать    15   0.978571     1
# 2     А     ему  промывать    15   0.978571     1
# 3     А   зачем  промывать    15   0.978571     1
# 4     А  знаете  промывать    15   0.978571     1

# %% [markdown]
# count the prob

# %%
import numpy as np
data_res['prob'] = np.where(data_res['word.id']==data_res['answer'], data_res.freq/data_res.summ, 0)
data_res
# Out:
#                                             shown    answer    word.id  summ  \
# 0                                               А       вот  промывать    15
# 1                                               А       где  промывать    15
# 2                                               А       ему  промывать    15
# 3                                               А     зачем  промывать    15
# 4                                               А    знаете  промывать    15
# 5                                               А      зори  промывать    15
# 6                                               А     когда  промывать    15
# 7                                               А       кто  промывать    15
# 8                                               А        он  промывать    15
# 9                                               А      петя  промывать    15
# 10                                              А       тем  промывать    15
# 11                                              А       тот  промывать    15
# 12                                              А        ты  промывать    15
# 13                                              А       что  промывать    15
# 14                                              А         я  промывать    15
# 15                                    А промывать     глаза     манную    15
# 16                                    А промывать     горло     манную    15
# 17                                    А промывать   желудок     манную    15
# 18                                    А промывать        ли     манную    15
# 19                                    А промывать  макароны     манную    15
# 20                                    А промывать     мозги     манную    15
# 21                                    А промывать     мозги     манную    15
# 22                                    А промывать     мозги     манную    15
# 23                                    А промывать   морковь     манную    15
# 24                                    А промывать       нос     манную    15
# 25                                    А промывать      рану     манную    15
# 26                                    А промывать      рану     манную    15
# 27                                    А промывать      рану     манную    15
# 28                                    А промывать      рану     манную    15
# 29                                    А промывать       рис     манную    15
# ...                                           ...       ...        ...   ...
# 57316        Я слезал‚ щупал стога‚ чтобы узнать‚       где      сухие    17
# 57317        Я слезал‚ щупал стога‚ чтобы узнать‚       где      сухие    17
# 57318        Я слезал‚ щупал стога‚ чтобы узнать‚       где      сухие    17
# 57319        Я слезал‚ щупал стога‚ чтобы узнать‚      есть      сухие    17
# 57320        Я слезал‚ щупал стога‚ чтобы узнать‚       как      сухие    17
# 57321        Я слезал‚ щупал стога‚ чтобы узнать‚       как      сухие    17
# 57322        Я слезал‚ щупал стога‚ чтобы узнать‚       как      сухие    17
# 57323        Я слезал‚ щупал стога‚ чтобы узнать‚    каково      сухие    17
# 57324        Я слезал‚ щупал стога‚ чтобы узнать‚       кто      сухие    17
# 57325        Я слезал‚ щупал стога‚ чтобы узнать‚      куда      сухие    17
# 57326        Я слезал‚ щупал стога‚ чтобы узнать‚        не      сухие    17
# 57327        Я слезал‚ щупал стога‚ чтобы узнать‚       что      сухие    17
# 57328        Я слезал‚ щупал стога‚ чтобы узнать‚       что      сухие    17
# 57329        Я слезал‚ щупал стога‚ чтобы узнать‚       что      сухие    17
# 57330        Я слезал‚ щупал стога‚ чтобы узнать‚       что      сухие    17
# 57331  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57332  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57333  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57334  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57335  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57336  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57337  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57338  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57339  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57340  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57341  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57342  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие        ли         ли    15
# 57343  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие       они         ли    15
# 57344  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие       они         ли    15
# 57345  Я слезал‚ щупал стога‚ чтобы узнать‚ сухие       они         ли    15
#
#        confusion  freq  prob
# 0       0.978571     1   0.0
# 1       0.978571     1   0.0
# 2       0.978571     1   0.0
# 3       0.978571     1   0.0
# 4       0.978571     1   0.0
# 5       0.978571     1   0.0
# 6       0.978571     1   0.0
# 7       0.978571     1   0.0
# 8       0.978571     1   0.0
# 9       0.978571     1   0.0
# 10      0.978571     1   0.0
# 11      0.978571     1   0.0
# 12      0.978571     1   0.0
# 13      0.978571     1   0.0
# 14      0.978571     1   0.0
# 15      0.978571     1   0.0
# 16      0.978571     1   0.0
# 17      0.978571     1   0.0
# 18      0.978571     1   0.0
# 19      0.978571     1   0.0
# 20      0.978571     3   0.0
# 21      0.978571     3   0.0
# 22      0.978571     3   0.0
# 23      0.978571     1   0.0
# 24      0.978571     1   0.0
# 25      0.978571     4   0.0
# 26      0.978571     4   0.0
# 27      0.978571     4   0.0
# 28      0.978571     4   0.0
# 29      0.978571     1   0.0
# ...          ...   ...   ...
# 57316   0.975714     4   0.0
# 57317   0.975714     4   0.0
# 57318   0.975714     4   0.0
# 57319   0.975714     1   0.0
# 57320   0.975714     3   0.0
# 57321   0.975714     3   0.0
# 57322   0.975714     3   0.0
# 57323   0.975714     1   0.0
# 57324   0.975714     1   0.0
# 57325   0.975714     1   0.0
# 57326   0.975714     1   0.0
# 57327   0.975714     4   0.0
# 57328   0.975714     4   0.0
# 57329   0.975714     4   0.0
# 57330   0.975714     4   0.0
# 57331   0.978571    12   0.8
# 57332   0.978571    12   0.8
# 57333   0.978571    12   0.8
# 57334   0.978571    12   0.8
# 57335   0.978571    12   0.8
# 57336   0.978571    12   0.8
# 57337   0.978571    12   0.8
# 57338   0.978571    12   0.8
# 57339   0.978571    12   0.8
# 57340   0.978571    12   0.8
# 57341   0.978571    12   0.8
# 57342   0.978571    12   0.8
# 57343   0.978571     3   0.0
# 57344   0.978571     3   0.0
# 57345   0.978571     3   0.0
#
# [57346 rows x 7 columns]

# %% [markdown]
# check: did I lost some examples or not, as we can see the

# %%
data_res = data_res.drop_duplicates()
j = data_res[['shown', 'prob']].groupby('shown').sum()
j = j.reset_index(level=['shown'])
k =  j.merge(data_res[['shown','word.id']], left_on=['shown'], right_on=['shown'], how='outer')
k = k.drop_duplicates()
s = k.groupby(['shown','word.id']).sum()
s = s.reset_index(level=['shown', 'word.id'])
result = data_res[['shown', 'word.id', 'prob', 'confusion']]
result = result.drop_duplicates()
print(result.shape, s.shape)
result['is_dub'] = result[['shown', 'word.id', 'confusion']].duplicated(keep=False)
g =  result.query('(is_dub == True & prob > 0)|(is_dub==False)')
g
# Out:
# (1853, 4) (1222, 3)
#                                                    shown       word.id  \
# 0                                                      А     промывать
# 15                                           А промывать        манную
# 40                                    А промывать манную         крупу
# 45                              А промывать манную крупу         перед
# 60                        А промывать манную крупу перед           тем
# 75                   А промывать манную крупу перед тем‚           как
# 90               А промывать манную крупу перед тем‚ как        варить
# 105       А промывать манную крупу перед тем‚ как варить            ее
# 123    А промывать манную крупу перед тем‚ как варить...            не
# 135    А промывать манную крупу перед тем‚ как варить...     пробовали
# 150                                                Автор   принадлежит
# 214                                    Автор принадлежит             к
# 320                                  Автор принадлежит к         числу
# 338                            Автор принадлежит к числу     последних
# 458                  Автор принадлежит к числу последних    свидетелей
# 507       Автор принадлежит к числу последних свидетелей      страшных
# 534    Автор принадлежит к числу последних свидетелей...       событий
# 625    Автор принадлежит к числу последних свидетелей...      прошлого
# 649    Автор принадлежит к числу последних свидетелей...          века
# 712                                                    В       темноте
# 713                                                    В          речи
# 714                                                    В      конверте
# 715                                                    В         котел
# 725                                                    В        сюжете
# 732                                                    В     багажнике
# 735                                                    В   современном
# 754                                                    В       вопросе
# 761                                                    В      качестве
# 764                                                    В           мои
# 777                                                    В           тот
# ...                                                  ...           ...
# 55708                                      Я люблю салат            из
# 55786                                   Я люблю салат из      картошки
# 55940                          Я люблю салат из картошки             с
# 55978                        Я люблю салат из картошки с       зеленью
# 56066               Я люблю салат из картошки с зеленью‚  заправленный
# 56150  Я люблю салат из картошки с зеленью‚ заправленный       пахучим
# 56297  Я люблю салат из картошки с зеленью‚ заправлен...  подсолнечным
# 56332  Я люблю салат из картошки с зеленью‚ заправлен...        маслом
# 56498                                          Я сделала           шаг
# 56575                                      Я сделала шаг     навстречу
# 56598                           Я сделала шаг навстречу:      приехала
# 56702                  Я сделала шаг навстречу: приехала             к
# 56772                Я сделала шаг навстречу: приехала к           ней
# 56927           Я сделала шаг навстречу: приехала к ней‚      попросив
# 56956  Я сделала шаг навстречу: приехала к ней‚ попросив     выслушать
# 57044  Я сделала шаг навстречу: приехала к ней‚ попро...          меня
# 57127                                          Я сказал‚           что
# 57142                                      Я сказал‚ что       русский
# 57157                              Я сказал‚ что русский        солдат
# 57172                       Я сказал‚ что русский солдат         омоет
# 57198                 Я сказал‚ что русский солдат омоет        сапоги
# 57201          Я сказал‚ что русский солдат омоет сапоги             в
# 57217        Я сказал‚ что русский солдат омоет сапоги в     индийском
# 57231  Я сказал‚ что русский солдат омоет сапоги в Ин...        океане
# 57245                                          Я слезал‚         щупал
# 57263                                    Я слезал‚ щупал         стога
# 57280                             Я слезал‚ щупал стога‚         чтобы
# 57297                       Я слезал‚ щупал стога‚ чтобы        узнать
# 57314               Я слезал‚ щупал стога‚ чтобы узнать‚         сухие
# 57331         Я слезал‚ щупал стога‚ чтобы узнать‚ сухие            ли
#
#            prob  confusion  is_dub
# 0      0.000000   0.978571   False
# 15     0.000000   0.978571   False
# 40     0.333333   0.978571    True
# 45     0.000000   0.978571   False
# 60     0.000000   0.978571   False
# 75     1.000000   0.978571   False
# 90     0.666667   0.978571    True
# 105    0.266667   0.978571    True
# 123    0.600000   0.978571    True
# 135    0.000000   0.978571   False
# 150    0.000000   0.910000   False
# 214    0.904762   0.910000    True
# 320    0.225806   0.911429    True
# 338    0.000000   0.908571   False
# 458    0.016129   0.911429    True
# 507    0.015873   0.910000    True
# 534    0.887097   0.911429    True
# 625    0.067797   0.915714    True
# 649    0.492063   0.910000    True
# 712    0.000000   0.000000   False
# 713    0.000000   0.000000   False
# 714    0.000000   0.000000   False
# 715    0.000000   0.000000   False
# 725    0.000000   0.000000   False
# 732    0.000000   0.000000   False
# 735    0.000000   0.000000   False
# 754    0.000000   0.000000   False
# 761    0.000000   0.000000   False
# 764    0.000000   0.000000   False
# 777    0.000000   0.000000   False
# ...         ...        ...     ...
# 55708  0.384615   0.870000    True
# 55786  0.000000   0.870000   False
# 55940  0.307692   0.870000    True
# 55978  0.021978   0.870000    True
# 56066  0.065934   0.870000    True
# 56150  0.000000   0.870000   False
# 56297  0.088889   0.871429    True
# 56332  0.988889   0.871429    True
# 56498  0.057471   0.875714    True
# 56575  0.177778   0.871429    True
# 56598  0.000000   0.878571   False
# 56702  0.314607   0.872857    True
# 56772  0.000000   0.872857   False
# 56927  0.011364   0.874286    True
# 56956  0.033708   0.872857    True
# 57044  0.752809   0.872857    True
# 57127  1.000000   0.978571   False
# 57142  0.000000   0.978571   False
# 57157  0.000000   0.978571   False
# 57172  0.000000   0.978571   False
# 57198  0.142857   0.980000    True
# 57201  0.533333   0.978571    True
# 57217  0.400000   0.978571    True
# 57231  1.000000   0.980000   False
# 57245  0.000000   0.974286   False
# 57263  0.000000   0.975714   False
# 57280  0.000000   0.975714   False
# 57297  0.000000   0.975714   False
# 57314  0.000000   0.975714   False
# 57331  0.800000   0.978571    True
#
# [1222 rows x 5 columns]

# %%
sub_data[['shown','word.id']].drop_duplicates().shape
# Out:
# (1222, 2)

# %%
import matplotlib.pyplot as plt 

plot_data = g[['shown', 'prob']]
def get_len(x):
    return len(x.split())
def plot_freq_probs(plot_data):
    plot_data['context_len'] = plot_data.shown.apply(get_len)
    x1 = plot_data.groupby('context_len').sum()
    x1 = x1.reset_index(level=['context_len'])
    x2 = plot_data.groupby('context_len').size()
    x2 = x2.reset_index(level=['context_len'])
    plotting = x1.merge(x2, left_on = 'context_len', right_on = 'context_len', how = 'outer')
    plotting.columns = ['context_len', 'prob', 'abs_freq']
    plotting['frequency'] = plotting['prob']/plotting['abs_freq']
    
    plt.subplot(211)
    plot1, =plt.plot(plotting.context_len.tolist(), plotting.prob.tolist(), 'b--', label="$y=x^2$")
    plt.ylim(0,60)
    plt.grid()

    plt.subplot(212)
    plt.bar(x= plotting.context_len.tolist(), height = plotting.frequency.tolist())
    plt.ylim(0,0.5)

    _=plt.show()
    
plot_freq_probs(plot_data)
# Out:
# /home/semen/.local/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
lstm = pd.read_excel('LSTM_prob_w_pos.xlsx')

# %%
lstm[['shown','answer']].drop_duplicates().shape
# Out:
# (1312, 2)

# %%
sub_lstm = lstm[['shown','answer', 'prob', 'pos.tag']]
sub_lstm = sub_lstm[sub_lstm.shown != 'Введите первое слово']
sub_lstm.shape
# Out:
# (1223, 4)

# %%
plot_data_lstm = sub_lstm[['shown', 'prob']]
plot_freq_probs(plot_data_lstm)
# Out:
# /home/semen/.local/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
ggg = g.merge(sub_lstm, left_on=['shown','word.id'], right_on=['shown','answer'], how='outer')
ress = ggg[['shown','word.id', 'prob_x', 'confusion', 'prob_y', 'pos.tag']]
ress
# Out:
#                                                   shown       word.id  \
# 0                                                     А     промывать
# 1                                           А промывать        манную
# 2                                    А промывать манную         крупу
# 3                              А промывать манную крупу         перед
# 4                        А промывать манную крупу перед           тем
# 5                   А промывать манную крупу перед тем‚           как
# 6               А промывать манную крупу перед тем‚ как        варить
# 7        А промывать манную крупу перед тем‚ как варить            ее
# 8     А промывать манную крупу перед тем‚ как варить...            не
# 9     А промывать манную крупу перед тем‚ как варить...     пробовали
# 10                                                Автор   принадлежит
# 11                                    Автор принадлежит             к
# 12                                  Автор принадлежит к         числу
# 13                            Автор принадлежит к числу     последних
# 14                  Автор принадлежит к числу последних    свидетелей
# 15       Автор принадлежит к числу последних свидетелей      страшных
# 16    Автор принадлежит к числу последних свидетелей...       событий
# 17    Автор принадлежит к числу последних свидетелей...      прошлого
# 18    Автор принадлежит к числу последних свидетелей...          века
# 19                                                    В       темноте
# 20                                                    В          речи
# 21                                                    В      конверте
# 22                                                    В         котел
# 23                                                    В        сюжете
# 24                                                    В     багажнике
# 25                                                    В   современном
# 26                                                    В       вопросе
# 27                                                    В      качестве
# 28                                                    В           мои
# 29                                                    В           тот
# ...                                                 ...           ...
# 1193                                      Я люблю салат            из
# 1194                                   Я люблю салат из      картошки
# 1195                          Я люблю салат из картошки             с
# 1196                        Я люблю салат из картошки с       зеленью
# 1197               Я люблю салат из картошки с зеленью‚  заправленный
# 1198  Я люблю салат из картошки с зеленью‚ заправленный       пахучим
# 1199  Я люблю салат из картошки с зеленью‚ заправлен...  подсолнечным
# 1200  Я люблю салат из картошки с зеленью‚ заправлен...        маслом
# 1201                                          Я сделала           шаг
# 1202                                      Я сделала шаг     навстречу
# 1203                           Я сделала шаг навстречу:      приехала
# 1204                  Я сделала шаг навстречу: приехала             к
# 1205                Я сделала шаг навстречу: приехала к           ней
# 1206           Я сделала шаг навстречу: приехала к ней‚      попросив
# 1207  Я сделала шаг навстречу: приехала к ней‚ попросив     выслушать
# 1208  Я сделала шаг навстречу: приехала к ней‚ попро...          меня
# 1209                                          Я сказал‚           что
# 1210                                      Я сказал‚ что       русский
# 1211                              Я сказал‚ что русский        солдат
# 1212                       Я сказал‚ что русский солдат         омоет
# 1213                 Я сказал‚ что русский солдат омоет        сапоги
# 1214          Я сказал‚ что русский солдат омоет сапоги             в
# 1215        Я сказал‚ что русский солдат омоет сапоги в     индийском
# 1216  Я сказал‚ что русский солдат омоет сапоги в Ин...        океане
# 1217                                          Я слезал‚         щупал
# 1218                                    Я слезал‚ щупал         стога
# 1219                             Я слезал‚ щупал стога‚         чтобы
# 1220                       Я слезал‚ щупал стога‚ чтобы        узнать
# 1221               Я слезал‚ щупал стога‚ чтобы узнать‚         сухие
# 1222         Я слезал‚ щупал стога‚ чтобы узнать‚ сухие            ли
#
#         prob_x  confusion        prob_y pos.tag
# 0     0.000000   0.978571  1.986770e-07    INFN
# 1     0.000000   0.978571  9.952960e-06    ADJF
# 2     0.333333   0.978571  9.152956e-02    NOUN
# 3     0.000000   0.978571  7.796750e-04    PREP
# 4     0.000000   0.978571  1.503523e-02    CONJ
# 5     1.000000   0.978571  9.661542e-01    CONJ
# 6     0.666667   0.978571  1.186796e-02    INFN
# 7     0.266667   0.978571  4.090891e-02    NPRO
# 8     0.600000   0.978571  1.469520e-01    PRCL
# 9     0.000000   0.978571  8.291220e-04    VERB
# 10    0.000000   0.910000  1.349750e-04    VERB
# 11    0.904762   0.910000  7.000707e-01    PREP
# 12    0.225806   0.911429  3.111598e-01    NOUN
# 13    0.000000   0.908571  1.234424e-02    ADJF
# 14    0.016129   0.911429  5.175420e-05    NOUN
# 15    0.015873   0.910000  6.572510e-05    ADJF
# 16    0.887097   0.911429  4.729219e-01    NOUN
# 17    0.067797   0.915714  2.835200e-02    ADJF
# 18    0.492063   0.910000  7.007810e-01    NOUN
# 19    0.000000   0.000000  1.612600e-04    NOUN
# 20    0.000000   0.000000  3.243340e-05    NOUN
# 21    0.000000   0.000000  8.010120e-06    NOUN
# 22    0.000000   0.000000  1.474280e-06    NOUN
# 23    0.000000   0.000000  3.578690e-05    NOUN
# 24    0.000000   0.000000  5.739320e-05    NOUN
# 25    0.000000   0.000000  2.667250e-04    ADJF
# 26    0.000000   0.000000  8.127780e-05    NOUN
# 27    0.000000   0.000000  6.771370e-03    NOUN
# 28    0.000000   0.000000  3.105170e-05    ADJF
# 29    0.000000   0.000000  4.990743e-03    ADJF
# ...        ...        ...           ...     ...
# 1193  0.384615   0.870000  3.144622e-01    PREP
# 1194  0.000000   0.870000  7.207496e-03    NOUN
# 1195  0.307692   0.870000  1.106943e-01    PREP
# 1196  0.021978   0.870000  4.130071e-03    NOUN
# 1197  0.065934   0.870000  3.231950e-04    PRTF
# 1198  0.000000   0.870000  2.960270e-05    ADJF
# 1199  0.088889   0.871429  2.354350e-03    ADJF
# 1200  0.988889   0.871429  8.389298e-01    NOUN
# 1201  0.057471   0.875714  2.333184e-02    NOUN
# 1202  0.177778   0.871429  4.213972e-02    ADVB
# 1203  0.000000   0.878571  1.392650e-04    VERB
# 1204  0.314607   0.872857  9.234519e-02    PREP
# 1205  0.000000   0.872857  2.722788e-02    NPRO
# 1206  0.011364   0.874286  5.005540e-05    GRND
# 1207  0.033708   0.872857  1.720860e-04    INFN
# 1208  0.752809   0.872857  1.379874e-01    NPRO
# 1209  1.000000   0.978571  8.797520e-01    CONJ
# 1210  0.000000   0.978571  2.741400e-04    ADJF
# 1211  0.000000   0.978571  4.676001e-03    NOUN
# 1212  0.000000   0.978571  0.000000e+00    VERB
# 1213  0.142857   0.980000  1.676980e-04    NOUN
# 1214  0.533333   0.978571  5.602126e-02    PREP
# 1215  0.400000   0.978571  4.944110e-04    ADJF
# 1216  1.000000   0.980000  1.589557e-01    NOUN
# 1217  0.000000   0.974286  1.478080e-04    VERB
# 1218  0.000000   0.975714  1.000420e-06    NOUN
# 1219  0.000000   0.975714  8.115414e-03    CONJ
# 1220  0.000000   0.975714  9.309831e-03    INFN
# 1221  0.000000   0.975714  2.216280e-06    ADJF
# 1222  0.800000   0.978571  5.757861e-01    PRCL
#
# [1223 rows x 6 columns]

# %%
row_data.shape
# Out:
# (57346, 16)

# %%
len(row_data.answer.tolist())
# Out:
# 57346
