# %%
# !ls
# Out:
# cloze_task_raw_data.xlsx  Compare_data.ipynb  LSTM_probability.xlsx

# %%
import pandas as pd
data = pd.read_excel('LSTM_probability.xlsx')
data_cloze = pd.read_excel('cloze_task_raw_data.xlsx')

# %%
data.head()
# Out:
#    item.id  word.serial.no                     shown     answer      prob
# 0        1               1      Введите первое слово         на  0.016503
# 1        1               2                        На    болотах  0.000006
# 2        1               3                На болотах  оставался  0.000138
# 3        1               4      На болотах оставался        еще  0.124899
# 4        1               5  На болотах оставался ещё        лед  0.002193

# %%
data_cloze.shape
# Out:
# (64645, 16)

# %%
#for each sentence replace 'Введите первое слово'  with 'Start_X' according to sentence id
data_cloze.shown.replace('Введите первое слово', 'Start', inplace=True)
data_cloze[data_cloze.shown=='Start']
d_c_start = data_cloze[['shown', 'item.id']]
d_c_start['item.id'] = d_c_start['item.id'].astype(str)
d_c_start.loc[d_c_start.shown == 'Start', 'XXX'] = d_c_start.shown+'_'+d_c_start['item.id']
# Out:
# /home/semen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/semen/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/semen/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_cloze['app'] = d_c_start.XXX
import numpy as np
data_cloze['shown'] = np.where(data_cloze['shown']=='Start', data_cloze.app , data_cloze.shown)
data_cloze = data_cloze.drop('app', axis=1)

# %%
data_cloze.shape, len(data_cloze.shown.unique())
# Out:
# ((64645, 16), 1309)

# %%
gb = data_cloze.groupby(['shown', 'answer', 'accuracy']).size()
gb = pd.DataFrame(gb,columns = ['fr'])
gb = gb.reset_index(level=['shown', 'answer', 'accuracy'])
gb.shape
# Out:
# (25528, 4)

# %%
gg= data_cloze.groupby(['shown', 'accuracy']).size()
gg = gg.reset_index(level=['shown', 'accuracy']) 
gg.columns = ['shown', 'accuracy', 'all_fr']
gg.head(), gg.shape
# Out:
# (       shown  accuracy  all_fr
#  0    Start_1       0.0     138
#  1   Start_10       0.0      70
#  2   Start_10       1.0       1
#  3  Start_100       0.0      16
#  4  Start_101       0.0      16, (1978, 3))

# %%
gk= gg[['shown', 'all_fr', 'accuracy']].groupby(['shown']).sum()
gk = gk.reset_index(level=['shown'])
gk.columns = ['shown', 'sum_fr', 'accuracy']
gk.head(), gk.shape
gk[gk.accuracy==1.].shape
# Out:
# (679, 3)

# %%
gg = gg.merge(gk, left_on='shown', right_on='shown', how='outer')

# %%
gg.head()
# Out:
#        shown  accuracy_x  all_fr  sum_fr  accuracy_y
# 0    Start_1         0.0     138     138         0.0
# 1   Start_10         0.0      70      71         1.0
# 2   Start_10         1.0       1      71         1.0
# 3  Start_100         0.0      16      16         0.0
# 4  Start_101         0.0      16      16         0.0

# %%
gg['prob'] = np.where(gg.accuracy_x==1., gg.all_fr/gg.sum_fr, 0)
res = gg[['shown', 'accuracy_x','sum_fr','prob']]
res = res[res.prob!=0.]
res.shape
# Out:
# (679, 4)

# %%
data.shown.unique().shape
# Out:
# (1170,)

# %%
data.shown.replace('Введите первое слово', 'Start', inplace=True)
#data[data.shown=='Start']
d_start = data[['shown', 'item.id']]
d_start['item.id'] = d_start['item.id'].astype(str)
d_start.loc[d_start.shown == 'Start', 'XXX'] = d_start.shown+'_'+d_c_start['item.id']
data['app'] = d_start.XXX
data['shown'] = np.where(data['shown']=='Start', data.app , data.shown)
data = data.drop('app', axis=1)
data.shown.unique().shape
# Out:
# /home/semen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/semen/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/semen/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# (1185,)

# %%
data_m =  data.merge(res, left_on='shown', right_on='shown', how='outer')

# %%
data_m.shown.unique().shape
# Out:
# (1206,)

# %%
data_m = data_m.dropna()
result = data_m[['shown', 'answer', 'prob_x', 'prob_y']]

# %%
check = data_cloze[data_cloze.accuracy==1.][['shown', 'answer']]
check = check.drop_duplicates()
data_result =  result.merge(check, left_on='shown', right_on='shown', how='outer')

# %%
data_result = data_result[data_result.answer_x == data_result.answer_y]
data_result = data_result[['shown','answer_x','prob_x','prob_y']]

# %%
data_result.columns = ['shown', 'answer', 'prob_by_model', 'prob_by_human']
data_result['R^2'] = (data_result.prob_by_human-data_result.prob_by_model)**2
data
# Out:
#                                                  shown        answer  \
# 0                                 На болотах оставался           еще
# 1                        На болотах оставался ещё лёд‚            но
# 2                     На болотах оставался ещё лёд‚ но            на
# 3                  На болотах оставался ещё лёд‚ но на       берегах
# 4          На болотах оставался ещё лёд‚ но на берегах          реки
# 5    На болотах оставался ещё лёд‚ но на берегах ре...         трава
# 11                                                  Он           был
# 12                              Он ловко поддел концом          ножа
# 13                Он ловко поддел концом ножа замочки‚             и
# 14              Он ловко поддел концом ножа замочки‚ и           они
# 15          Он ловко поддел концом ножа замочки‚ и они     отскочили
# 16                                   Ваня раскрыл было           рот
# 17                              Ваня раскрыл было рот‚            но
# 18                           Ваня раскрыл было рот‚ но         понял
# 19                    Ваня раскрыл было рот‚ но понял‚           что
# 20         Ваня раскрыл было рот‚ но понял‚ что что-то            не
# 21      Ваня раскрыл было рот‚ но понял‚ что что-то не           так
# 22   Ваня раскрыл было рот‚ но понял‚ что что-то не...             и
# 23   Ваня раскрыл было рот‚ но понял‚ что что-то не...     промолчал
# 24                                          Сделав мне          знак
# 25                          Сделав мне знак помолчать‚            он
# 26                       Сделав мне знак помолчать‚ он      приложил
# 27              Сделав мне знак помолчать‚ он приложил           ухо
# 28          Сделав мне знак помолчать‚ он приложил ухо             к
# 29        Сделав мне знак помолчать‚ он приложил ухо к         двери
# 34                                                   Я         люблю
# 35                                           Я сделала           шаг
# 36                                       Я сделала шаг     навстречу
# 37                   Я сделала шаг навстречу: приехала             к
# 38            Я сделала шаг навстречу: приехала к ней‚      попросив
# ..                                                 ...           ...
# 733  Считается‚ что коллекционирование раритетных м...   шоу-бизнеса
# 734                                Торговля продуктами       питания
# 735                        Торговля продуктами питания      является
# 736               Торговля продуктами питания является         одной
# 737         Торговля продуктами питания является одной            из
# 738      Торговля продуктами питания является одной из         самых
# 739  Торговля продуктами питания является одной из ...    прибыльных
# 740  Торговля продуктами питания является одной из ...      отраслей
# 741  Торговля продуктами питания является одной из ...             в
# 743                                   Клиенты воровали            из
# 744        Один футболист‚ который получил растяжение‚            не
# 745  Один футболист‚ который получил растяжение‚ не...             в
# 746  Один футболист‚ который получил растяжение‚ не...          игре
# 747                              Наши власти позволяют          себе
# 748  Наши власти позволяют себе излишества‚ создава...      общества
# 749                         Ненужный коврик из твёрдой    пластмассы
# 750  Ненужный коврик из твёрдой пластмассы пригодит...     подставка
# 751  Ненужный коврик из твёрдой пластмассы пригодит...           для
# 752  Ненужный коврик из твёрдой пластмассы пригодит...        посуды
# 753              Когда родители пригрозили не взять её             с
# 754            Когда родители пригрозили не взять её с         собой
# 755     Когда родители пригрозили не взять её с собой‚          маша
# 756  Когда родители пригрозили не взять её с собой‚...  расстроилась
# 757                                        От внимания   наблюдателя
# 758                            От внимания наблюдателя            не
# 759                         От внимания наблюдателя не        должна
# 760                  От внимания наблюдателя не должна    ускользать
# 761       От внимания наблюдателя не должна ускользать          даже
# 762  От внимания наблюдателя не должна ускользать даже      малейшая
# 763  От внимания наблюдателя не должна ускользать д...        деталь
#
#      prob_by_model  prob_by_human           R^2
# 0         0.124899       0.029412  9.117721e-03
# 1         0.039917       0.362963  1.043589e-01
# 2         0.031502       0.043796  1.511303e-04
# 3         0.003701       0.007299  1.294580e-05
# 4         0.014212       0.080882  4.444963e-03
# 5         0.003874       0.192593  3.561461e-02
# 11        0.048258       0.006711  1.726100e-03
# 12        0.045508       0.102941  3.298552e-03
# 13        0.051944       0.355556  9.217985e-02
# 14        0.072151       0.187970  1.341391e-02
# 15        0.002742       0.014706  1.431301e-04
# 16        0.467625       0.225225  5.875769e-02
# 17        0.661029       0.790909  1.686880e-02
# 18        0.004546       0.018349  1.905118e-04
# 19        0.958914       0.962963  1.639039e-05
# 20        0.241922       0.523364  7.921003e-02
# 21        0.575578       0.761468  3.455488e-02
# 22        0.452314       0.528302  5.774183e-03
# 23        0.000886       0.125000  1.540423e-02
# 24        0.002992       0.010309  5.354131e-05
# 25        0.164170       0.729167  3.192215e-01
# 26        0.000852       0.010417  9.148500e-05
# 27        0.115581       0.085106  9.287244e-04
# 28        0.826187       0.905263  6.253093e-03
# 29        0.015418       0.484211  2.197665e-01
# 34        0.003210       0.008734  3.051129e-05
# 35        0.023332       0.056818  1.121335e-03
# 36        0.042140       0.177778  1.839768e-02
# 37        0.092345       0.303371  4.453180e-02
# 38        0.000050       0.011364  1.279971e-04
# ..             ...            ...           ...
# 733       0.089278       0.066667  5.112773e-04
# 734       0.163265       0.230769  4.556833e-03
# 735       0.004347       0.083333  6.238855e-03
# 736       0.077346       0.076923  1.787859e-07
# 737       0.995638       0.933333  3.881836e-03
# 738       0.292348       0.285714  4.400613e-05
# 739       0.017299       0.285714  7.204701e-02
# 740       0.305058       0.333333  7.994775e-04
# 741       0.100149       0.076923  5.394517e-04
# 743       0.028697       0.083333  2.985102e-03
# 744       0.035322       0.333333  8.881070e-02
# 745       0.095617       0.928571  6.938137e-01
# 746       0.015405       0.357143  1.167845e-01
# 747       0.215054       0.307692  8.581789e-03
# 748       0.001888       0.230769  5.238640e-02
# 749       0.010510       0.083333  5.303263e-03
# 750       0.000019       0.333333  1.110982e-01
# 751       0.512068       0.571429  3.523681e-03
# 752       0.008749       0.083333  5.562781e-03
# 753       0.098012       0.538462  1.939961e-01
# 754       0.859795       0.846154  1.860755e-04
# 755       0.000831       0.083333  6.806588e-03
# 756       0.051342       0.461538  1.682608e-01
# 757       0.000024       0.019608  3.835426e-04
# 758       0.042131       0.058824  2.786424e-04
# 759       0.000957       0.020000  3.626235e-04
# 760       0.000054       0.040000  1.595655e-03
# 761       0.009129       0.039216  9.052350e-04
# 762       0.005202       0.215686  4.430383e-02
# 763       0.148185       0.711538  3.173669e-01
#
# [660 rows x 5 columns]

# %%
data_result
