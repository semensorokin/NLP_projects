# %%
# -*- encoding: utf-8 -*-
import urllib.request  # the lib that handles the url stuff

data = urllib.request.urlopen('https://raw.githubusercontent.com/UniversalDependencies/UD_Japanese-PUD/master/ja_pud-ud-test.conllu') # it's a file like object and works just like a file
for line in list(data)[:3]: # files are iterable
  print (line)
# Out:
# b'# newdoc id = n01001\n'
# b'# sent_id = n01001011\n'
# ...

# %%
# !pip install urllib
# Out:
# ...
#   Could not find a version that satisfies the requirement urllib (from versions: )
# No matching distribution found for urllib
